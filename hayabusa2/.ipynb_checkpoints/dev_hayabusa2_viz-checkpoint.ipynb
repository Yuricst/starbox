# %% [markdown]
# # Visualize Hayabusa2 trajectory
#
# Yuri Shimane, 2020/10/21
#
# Data taken from: https://www.jaxa.jp/projects/sas/hayabusa2/pdf/traplaninfo20150430.pdf
#
#
# Unofficial translation on the dataset header description:
#
# 1. The generated data is for visualization of Hayabusa2's trajectory within the solar system. The actual trajectory may differ from the generated dataset with future orbital determination and correction maneuvers.
#
# 2. The data is released for public outreach activities; data usage policy may be viewed at: http://www.jaxa.jp/policy_j.html
#
# 3. The data is a preliminary trajectory based on information obtained at the launch date, and may differ from the actual flown trajectory.
#
# 4. Numerical accuracy: 0.0001au (~15,000 km)
#
# 5. The trajectory data inccludes the period from launch up to approach to Ryugu (~6,000 km)
#
# 6. Unless significant modification occurs midflight, the trajectory in this data is not modified.
#
#
# #### Dependencies
#
# Non-standard modules used in this Notebook is spiceypy, a Python wrapper for NAIF SPICE functions. For installation, run
# ```python
# pip install spiceypy
# ```
# or
# ```python
# conda config --add channels conda-forge
# conda install spiceypy
# ```
#
# https://spiceypy.readthedocs.io/en/master/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import spiceypy as spice

# %% [markdown]
# ### Load NAIF SPICE kernel
#
# SPICE kernels are data files which are used within the SPICE framework. Here, we load the standard ephemeris second kernel for handling time-related data.

# %%
# load ephemeris-second spice kernel for UTC to ephemeris second conversion
spice.furnsh('./naif0012.tls')

# %% [markdown]
# ### Load dataset
# The data distributed as a pdf file has been saved a priori as a .csv for easier handling.
# The entries in the data are:
#
# ```
# - L+      : time since launch [day]
# - X, Y, Z : cooridnates of the spacecraft (Hbs2), Earth, and Ryugu (1999JU3) in the ecliptic coordinate system [AU]
# - Rs      : spacecraft-Sun distance [10^4 km]
# - Re      : spacecraft-Earth distance [10^4 km]
# - Vs      : spacecarft speed w.r.t. Sun [km/s]
# - Ve      : spacecraft speed w.r.t. Earth [km/s]
# - alpha   : right ascension w.r.t. Earth [deg]
# - delta   : declination w.r.t. Earth [deg]
# - Dflt    : Flight distance [10^4 km]
# ```

# %%
# load data as pandas dataframe
data = pd.read_csv("traplaninfo20150430.csv")
# get beginning and end of data as strings
tstart, tend = data.iloc[0,:]["UTC"], data.iloc[-1,:]["UTC"]
data
# Out:
#                       UTC      L+    X_Hbs2    Y_Hbs2    Z_Hbs2   X_Earth  \
# 0     2014/12/03.05:00:00     0.0  0.325037  0.930594 -0.000010  0.325234
# 1     2014/12/04.05:00:00     1.0  0.309534  0.937664 -0.002231  0.308668
# 2     2014/12/05.05:00:00     2.0  0.293598  0.944389 -0.004351  0.292008
# 3     2014/12/06.05:00:00     3.0  0.277564  0.950806 -0.006443  0.275259
# 4     2014/12/07.05:00:00     4.0  0.261440  0.956926 -0.008523  0.258425
# ...                   ...     ...       ...       ...       ...       ...
# 1275  2018/05/31.05:00:00  1275.0 -0.178935  0.945280 -0.048265 -0.355620
# 1276  2018/06/01.05:00:00  1276.0 -0.197571  0.941389 -0.049961 -0.339745
# 1277  2018/06/02.05:00:00  1277.0 -0.216144  0.937186 -0.051640 -0.323774
# 1278  2018/06/03.05:00:00  1278.0 -0.234646  0.932673 -0.053302 -0.307711
# 1279  2018/06/04.05:00:00  1279.0 -0.253072  0.927849 -0.054947 -0.291559
#
#        Y_Earth   Z_Earth  X_1999JU3  Y_1999JU3  Z_1999JU3       Rs       Re  \
# 0     0.930600 -0.000031  -0.805848  -1.019952  -0.045649  14746.2      3.0
# 1     0.936062 -0.000030  -0.796246  -1.030534  -0.044366  14771.8     42.7
# 2     0.941235 -0.000030  -0.786536  -1.040977  -0.043077  14795.0     83.5
# 3     0.946119 -0.000030  -0.776723  -1.051282  -0.041782  14817.9    123.7
# 4     0.950711 -0.000029  -0.766806  -1.061448  -0.040482  14840.6    163.8
# ...        ...       ...        ...        ...        ...      ...      ...
# 1275 -0.949381  0.000040  -0.178914   0.945334  -0.048264  14410.4  28475.9
# 1276 -0.955346  0.000041  -0.197557   0.941438  -0.049961  14409.2  28464.2
# 1277 -0.961041  0.000042  -0.216135   0.937231  -0.051640  14408.9  28453.2
# 1278 -0.966464  0.000042  -0.234641   0.932713  -0.053303  14409.5  28442.9
# 1279 -0.971615  0.000043  -0.253069   0.927886  -0.054948  14410.9  28433.3
#
#            Ra     Vs     Ve   alpha  delta      Dflt
# 0     33736.3  23.54   6.92 -175.83   4.86       0.0
# 1     33778.4  30.20   4.78   69.75 -28.92     257.1
# 2     33816.6  30.15   4.68   70.98 -29.05     517.8
# 3     33853.9  30.10   4.64   71.41 -29.08     778.0
# 4     33890.3  30.05   4.63   71.63 -29.08    1037.9
# ...       ...    ...    ...     ...    ...       ...
# 1275      0.9  33.09  59.93   84.26  21.88  313272.5
# 1276      0.8  33.10  59.94   85.38  21.86  313558.5
# 1277      0.7  33.10  59.94   86.50  21.84  313844.4
# 1278      0.6  33.10  59.94   87.63  21.81  314130.4
# 1279      0.6  33.10  59.94   88.75  21.78  314416.4
#
# [1280 rows x 19 columns]

# %%
# generic plot, rotating frames
plt.rcParams["font.size"] = 20
fig, axs = plt.subplots(1, 1, figsize=(12, 8))

axs.scatter(0, 0, c='orange', label='Sun', s=120)
axs.plot(data['X_Hbs2'], data['Y_Hbs2'], c='deeppink', label='Hayabusa2', linestyle='--')
axs.plot(data['X_Earth'], data['Y_Earth'], c='b', label='Earth', linestyle=':')
axs.plot(data['X_1999JU3'], data['Y_1999JU3'], c='gray', label='Ryugu', linestyle=':')

axs.axis('equal')
axs.grid(True)
axs.set_xlabel('x, AU')
axs.set_ylabel('y, AU')
axs.set_title(f'Hayabusa2 Data, {tstart} ~ {tend}')
axs.legend(loc='lower right')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# ### Infer velocity vector
# Since the data-set only offer position information (along with time), the velocity components are infered by Euler scheme central difference (forward/backward for the first and last data-points)

# %%
# define conversion from AU to km
au2km = 149597870700.0/1e3
au2km
# Out:
# 149597870.7

# %%
for idx in tqdm(range(len(data)), desc='Infer velocities: '):
    VX_Hbs2,    VY_Hbs2,    VZ_Hbs2    = np.zeros(len(data),), np.zeros(len(data),), np.zeros(len(data),)
    VX_Earth,   VY_Earth,   VZ_Earth   = np.zeros(len(data),), np.zeros(len(data),), np.zeros(len(data),)
    VX_1999JU3, VY_1999JU3, VZ_1999JU3 = np.zeros(len(data),), np.zeros(len(data),), np.zeros(len(data),)
    # for first data: use forward difference
    if idx == 0:
        dt_min = spice.utc2et( data.iloc[idx,:]['UTC'].replace('/', '-').replace('.','T') )
        dt_pls = spice.utc2et( data.iloc[idx+1,:]['UTC'].replace('/', '-').replace('.','T') )
        dt     = dt_pls - dt_min
        # hayabusa2
        VX_Hbs2[idx] = (data.iloc[idx+1,:]['X_Hbs2'] - data.iloc[idx,:]['X_Hbs2']) / dt   # forward diff
        VY_Hbs2[idx] = (data.iloc[idx+1,:]['Y_Hbs2'] - data.iloc[idx,:]['Y_Hbs2']) / dt   # forward diff
        VZ_Hbs2[idx] = (data.iloc[idx+1,:]['Z_Hbs2'] - data.iloc[idx,:]['Z_Hbs2']) / dt   # forward diff
        # earth
        VX_Earth[idx] = (data.iloc[idx+1,:]['X_Hbs2'] - data.iloc[idx,:]['X_Hbs2']) / dt   # forward diff
        VY_Earth[idx] = (data.iloc[idx+1,:]['Y_Hbs2'] - data.iloc[idx,:]['Y_Hbs2']) / dt   # forward diff
        VZ_Earth[idx] = (data.iloc[idx+1,:]['Z_Hbs2'] - data.iloc[idx,:]['Z_Hbs2']) / dt   # forward diff
        # ryugu
        VX_1999JU3[idx] = (data.iloc[idx+1,:]['X_Hbs2'] - data.iloc[idx,:]['X_Hbs2']) / dt   # forward diff
        VY_1999JU3[idx] = (data.iloc[idx+1,:]['Y_Hbs2'] - data.iloc[idx,:]['Y_Hbs2']) / dt   # forward diff
        VZ_1999JU3[idx] = (data.iloc[idx+1,:]['Z_Hbs2'] - data.iloc[idx,:]['Z_Hbs2']) / dt   # forward diff
    # for final data: use backward difference
    elif idx == len(data)-1:
        dt_min = spice.utc2et( data.iloc[idx-1,:]['UTC'].replace('/', '-').replace('.','T') )
        dt_pls = spice.utc2et( data.iloc[idx,:]['UTC'].replace('/', '-').replace('.','T') )
        dt     = dt_pls - dt_min
        # hayabusa2
        VX_Hbs2[idx] = (data.iloc[idx,:]['X_Hbs2'] - data.iloc[idx-1,:]['X_Hbs2']) / dt   # backward diff
        VY_Hbs2[idx] = (data.iloc[idx,:]['Y_Hbs2'] - data.iloc[idx-1,:]['Y_Hbs2']) / dt   # backward diff
        VZ_Hbs2[idx] = (data.iloc[idx,:]['Z_Hbs2'] - data.iloc[idx-1,:]['Z_Hbs2']) / dt   # backward diff
        # earth
        VX_Earth[idx] = (data.iloc[idx,:]['X_Hbs2'] - data.iloc[idx-1,:]['X_Hbs2']) / dt   # backward diff
        VY_Earth[idx] = (data.iloc[idx,:]['Y_Hbs2'] - data.iloc[idx-1,:]['Y_Hbs2']) / dt   # backward diff
        VZ_Earth[idx] = (data.iloc[idx,:]['Z_Hbs2'] - data.iloc[idx-1,:]['Z_Hbs2']) / dt   # backward diff
        # ryugu
        VX_1999JU3[idx] = (data.iloc[idx,:]['X_Hbs2'] - data.iloc[idx-1,:]['X_Hbs2']) / dt   # backward diff
        VY_1999JU3[idx] = (data.iloc[idx,:]['Y_Hbs2'] - data.iloc[idx-1,:]['Y_Hbs2']) / dt   # backward diff
        VZ_1999JU3[idx] = (data.iloc[idx,:]['Z_Hbs2'] - data.iloc[idx-1,:]['Z_Hbs2']) / dt   # backward diff
        
    # for all other data: use central difference
    else:
        dt_min = spice.utc2et( data.iloc[idx-1,:]['UTC'].replace('/', '-').replace('.','T') )
        dt_pls = spice.utc2et( data.iloc[idx+1,:]['UTC'].replace('/', '-').replace('.','T') )
        dt     = dt_pls - dt_min
        # hayabusa2
        VX_Hbs2[idx] = (data.iloc[idx+1,:]['X_Hbs2'] - data.iloc[idx-1,:]['X_Hbs2']) / (2*dt)   # central diff
        VY_Hbs2[idx] = (data.iloc[idx+1,:]['Y_Hbs2'] - data.iloc[idx-1,:]['Y_Hbs2']) / (2*dt)   # central diff
        VZ_Hbs2[idx] = (data.iloc[idx+1,:]['Z_Hbs2'] - data.iloc[idx-1,:]['Z_Hbs2']) / (2*dt)   # central diff
        # earth
        VX_Earth[idx] = (data.iloc[idx+1,:]['X_Hbs2'] - data.iloc[idx-1,:]['X_Hbs2']) / (2*dt)   # central diff
        VY_Earth[idx] = (data.iloc[idx+1,:]['Y_Hbs2'] - data.iloc[idx-1,:]['Y_Hbs2']) / (2*dt)   # central diff
        VZ_Earth[idx] = (data.iloc[idx+1,:]['Z_Hbs2'] - data.iloc[idx-1,:]['Z_Hbs2']) / (2*dt)   # central diff
        # ryugu
        VX_1999JU3[idx] = (data.iloc[idx+1,:]['X_Hbs2'] - data.iloc[idx-1,:]['X_Hbs2']) / (2*dt)   # central diff
        VY_1999JU3[idx] = (data.iloc[idx+1,:]['Y_Hbs2'] - data.iloc[idx-1,:]['Y_Hbs2']) / (2*dt)   # central diff
        VZ_1999JU3[idx] = (data.iloc[idx+1,:]['Z_Hbs2'] - data.iloc[idx-1,:]['Z_Hbs2']) / (2*dt)   # central diff
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Infer velocity: ', max=1280.0, style=ProgressStyle(descri…

# %%
data
# Out:
#                       UTC      L+    X_Hbs2    Y_Hbs2    Z_Hbs2   X_Earth  \
# 0     2014/12/03.05:00:00     0.0  0.325037  0.930594 -0.000010  0.325234
# 1     2014/12/04.05:00:00     1.0  0.309534  0.937664 -0.002231  0.308668
# 2     2014/12/05.05:00:00     2.0  0.293598  0.944389 -0.004351  0.292008
# 3     2014/12/06.05:00:00     3.0  0.277564  0.950806 -0.006443  0.275259
# 4     2014/12/07.05:00:00     4.0  0.261440  0.956926 -0.008523  0.258425
# ...                   ...     ...       ...       ...       ...       ...
# 1275  2018/05/31.05:00:00  1275.0 -0.178935  0.945280 -0.048265 -0.355620
# 1276  2018/06/01.05:00:00  1276.0 -0.197571  0.941389 -0.049961 -0.339745
# 1277  2018/06/02.05:00:00  1277.0 -0.216144  0.937186 -0.051640 -0.323774
# 1278  2018/06/03.05:00:00  1278.0 -0.234646  0.932673 -0.053302 -0.307711
# 1279  2018/06/04.05:00:00  1279.0 -0.253072  0.927849 -0.054947 -0.291559
#
#        Y_Earth   Z_Earth  X_1999JU3  Y_1999JU3  Z_1999JU3       Rs       Re  \
# 0     0.930600 -0.000031  -0.805848  -1.019952  -0.045649  14746.2      3.0
# 1     0.936062 -0.000030  -0.796246  -1.030534  -0.044366  14771.8     42.7
# 2     0.941235 -0.000030  -0.786536  -1.040977  -0.043077  14795.0     83.5
# 3     0.946119 -0.000030  -0.776723  -1.051282  -0.041782  14817.9    123.7
# 4     0.950711 -0.000029  -0.766806  -1.061448  -0.040482  14840.6    163.8
# ...        ...       ...        ...        ...        ...      ...      ...
# 1275 -0.949381  0.000040  -0.178914   0.945334  -0.048264  14410.4  28475.9
# 1276 -0.955346  0.000041  -0.197557   0.941438  -0.049961  14409.2  28464.2
# 1277 -0.961041  0.000042  -0.216135   0.937231  -0.051640  14408.9  28453.2
# 1278 -0.966464  0.000042  -0.234641   0.932713  -0.053303  14409.5  28442.9
# 1279 -0.971615  0.000043  -0.253069   0.927886  -0.054948  14410.9  28433.3
#
#            Ra     Vs     Ve   alpha  delta      Dflt
# 0     33736.3  23.54   6.92 -175.83   4.86       0.0
# 1     33778.4  30.20   4.78   69.75 -28.92     257.1
# 2     33816.6  30.15   4.68   70.98 -29.05     517.8
# 3     33853.9  30.10   4.64   71.41 -29.08     778.0
# 4     33890.3  30.05   4.63   71.63 -29.08    1037.9
# ...       ...    ...    ...     ...    ...       ...
# 1275      0.9  33.09  59.93   84.26  21.88  313272.5
# 1276      0.8  33.10  59.94   85.38  21.86  313558.5
# 1277      0.7  33.10  59.94   86.50  21.84  313844.4
# 1278      0.6  33.10  59.94   87.63  21.81  314130.4
# 1279      0.6  33.10  59.94   88.75  21.78  314416.4
#
# [1280 rows x 19 columns]

# %%
utc_converted = data.iloc[0,:]['UTC'].replace('/', '-').replace('.','T')
# Out:
# '2014-12-03T05:00:00'

# %%
spice.utc2et(data.iloc[0,:]['UTC'].replace('/', '-').replace('.','T'))
# Out:
# ---------------------------------------------------------------------------
# SpiceINVALIDTIMESTRING                    Traceback (most recent call last)
# <ipython-input-56-a011c3fe6c05> in <module>
# ----> 1 spice.utc2et(data.iloc[0,:]['UTC'])
#
# ~\Anaconda3\lib\site-packages\spiceypy\spiceypy.py in with_errcheck(*args, **kwargs)
#     106         try:
#     107             res = f(*args, **kwargs)
# --> 108             check_for_spice_error(f)
#     109             return res
#     110         except BaseException:
#
# ~\Anaconda3\lib\site-packages\spiceypy\spiceypy.py in check_for_spice_error(f)
#      90         reset()
#      91         raise stypes.dynamically_instantiate_spiceyerror(
# ---> 92             short=short, explain=explain, long=long, traceback=traceback
#      93         )
#      94
#
# SpiceINVALIDTIMESTRING:
# ================================================================================
#
# Toolkit version: CSPICE66
#
# SPICE(INVALIDTIMESTRING) --
# Time String Could Not Be Parsed
# The meaning of the decimal number <03.05> could not be determined: 2014/12/<03.05>:00:00
#
# utc2et_c --> UTC2ET
#
# ================================================================================

# %%
1996-12-18T12:28:28           1996 Dec   na  18  12  28 28
1986-01-18T12                 1986 Jan   na  18  12  00 00
1986-01-18T12:19              1986 Jan   na  18  12  19 00
1986-01-18T12:19:52.18        1986 Jan   na  18  12  19 52.18
1995-08T18:28:12              1995  na  008  na  18  28 12
1995-18T                      1995  na  018  na  00  00 00

# %% [markdown]
# ### Osculating elements
#
# Orbital elements of the object
